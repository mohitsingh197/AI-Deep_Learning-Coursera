# %%
#!wget https://vignette.wikia.nocookie.net/liberapedia/images/b/bc/Elephant.jpg/revision/latest?cb=20130413020301 #elephanr
#!wget https://upload.wikimedia.org/wikipedia/commons/7/76/Tetragonula_carbonaria_%2814521993792%29.jpg #bee
# !wget http://bharatdiscovery.org/bharatkosh/w/images/1/10/Langur.jpg #langur
# Out:
# --2018-04-26 04:22:20--  http://bharatdiscovery.org/bharatkosh/w/images/1/10/Langur.jpg
# Resolving bharatdiscovery.org (bharatdiscovery.org)... 104.24.98.7, 104.24.99.7, 2400:cb00:2048:1::6818:6207, ...
# Connecting to bharatdiscovery.org (bharatdiscovery.org)|104.24.98.7|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 308799 (302K) [image/jpeg]
# Saving to: ‘Langur.jpg’
#
# 100%[======================================>] 308,799     --.-K/s   in 0.1s
#
# 2018-04-26 04:22:20 (2.80 MB/s) - ‘Langur.jpg’ saved [308799/308799]

# %%
#!mv latest?cb=20130413020301 elephant.jpg
#!mv Tetragonula_carbonaria_(14521993792).jpg bee.jpg
# Out:
# /bin/sh: -c: line 0: syntax error near unexpected token `('
# /bin/sh: -c: line 0: `mv Tetragonula_carbonaria_(14521993792).jpg bee.jpg'

# %%
from keras.applications.resnet50 import ResNet50
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# This is an already trained model in imagenet dataset which contains 14 million images. This is called transfer learning
model = ResNet50(weights='imagenet') 

#img_path = 'elephant.jpg'
#img_path = 'Tetragonula_carbonaria_(14521993792).jpg' #bee
img_path = 'Langur.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x.shape
# Out:
# (224, 224, 3)

# %%
x = np.expand_dims(x, axis=0)
print(x.shape)
# Out:
# (1, 224, 224, 3)

# %%
x = preprocess_input(x)

# %%
preds = model.predict(x)

# %%
preds
# Out:
# array([[  1.52435234e-07,   8.10028837e-07,   2.48417479e-07,
#           3.54246268e-08,   7.83616031e-07,   2.45079548e-07,
#           5.72496859e-08,   1.05433799e-06,   1.87109583e-06,
#           4.34465710e-06,   4.06853843e-07,   1.59797310e-06,
#           6.64049992e-07,   2.55562463e-06,   7.28087684e-07,
#           6.45672742e-07,   3.03628622e-06,   1.19974811e-05,
#           3.14510612e-06,   1.98107926e-04,   7.09145638e-07,
#           3.24786515e-06,   1.02016804e-06,   6.87417014e-06,
#           9.62618105e-06,   2.98368889e-07,   1.34974684e-07,
#           1.26784514e-07,   3.39908013e-07,   3.10989805e-07,
#           1.89402485e-07,   8.55283588e-07,   3.45149829e-07,
#           1.88158793e-07,   4.04157248e-07,   1.31419870e-06,
#           3.82103781e-06,   2.02891897e-07,   1.32117478e-07,
#           1.32494063e-06,   8.69843348e-07,   3.79093905e-07,
#           4.63290831e-07,   3.67033817e-06,   1.92934590e-06,
# ...

# %%
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357), (u'n02504458', u'African_elephant', 0.061040461)]
# Out:
# ('Predicted:', [(u'n02488291', u'langur', 0.85514838), (u'n02484975', u'guenon', 0.08238785), (u'n02488702', u'colobus', 0.021788446)])
